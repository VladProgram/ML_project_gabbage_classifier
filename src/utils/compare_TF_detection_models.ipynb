# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

def save_html_table_to_csv():
	table = pd.read_html('https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md')[0]

	table.to_csv('./TF_detection_models_table.csv', index=False)


# save_html_table_to_csv()

table = pd.read_csv('./TF_detection_models_table.csv')
table['Speed (ms)'].astype(float)
table['COCO mAP'].astype(float)
sorted = table.sort_values(by=['COCO mAP', 'Speed (ms)'], ascending = [False, True])
# sorted = table.sort_values(by='COCO mAP')
sorted
# Out:
#                                        Model name  Speed (ms)  COCO mAP  \
# 18                      EfficientDet D7 1536x1536         325      51.2
# 17                      EfficientDet D6 1280x1280         268      50.5
# 16                      EfficientDet D5 1280x1280         222      49.7
# 15                      EfficientDet D4 1024x1024         133      48.5
# 14                        EfficientDet D3 896x896          95      45.4
# 2                CenterNet HourGlass104 1024x1024         197      44.5
# 3      CenterNet HourGlass104 Keypoints 1024x1024         211      42.8
# 0                  CenterNet HourGlass104 512x512          70      41.9
# 13                        EfficientDet D2 768x768          67      41.8
# 10    CenterNet MobileNetV2 FPN Keypoints 512x512           6      41.7
# 1        CenterNet HourGlass104 Keypoints 512x512          76      40.0
# 28  SSD ResNet152 V1 FPN 1024x1024 (RetinaNet152)         111      39.6
# ...
